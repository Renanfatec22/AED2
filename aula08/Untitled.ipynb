# %%
# Remove um nó da lista encadeada
def remover(self, item):
# Aponta a referência corrente para cabeça de L
atual = self.head
# Aponta referência anterior para None
anterior = Nenhum
encontrado = Falso
# Enquanto não encontrar o valor a ser removido
enquanto não encontrado e atual! = Nenhum:
# Se não houver corrente armazenada o item desejado, encontrado
se current.get_data() == item:
encontrado = Verdadeiro
outro:
#Se não há corrente não é o que procuramos
# Atualiza o anterior e o atual
anterior = atual
atual = atual.get_next()
# Se não for removido para o primeiro da lista
# Altere a cabeça da lista
se anterior == Nenhum:
self.head = atual.get_next()
outro:
# Caso não seja primeiro nó, liga o anterior com o próximo
anterior.set_next(atual.get_next())
# Desliga nó corrente
atual.set_next(Nenhum)
